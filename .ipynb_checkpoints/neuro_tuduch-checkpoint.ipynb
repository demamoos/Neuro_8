# %%
from sklearn.datasets import make_blobs, make_moons
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
from sklearn.datasets import load_breast_cancer

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
breast_cancer_data = load_breast_cancer()

# %%
print(breast_cancer_data['DESCR'])
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         largest values) of these features were computed for each image,
#         resulting in 30 features.  For instance, field 3 is Mean Radius, field
#         13 is Radius SE, field 23 is Worst Radius.
#
#         - class:
#                 - WDBC-Malignant
#                 - WDBC-Benign
#
#     :Summary Statistics:
#
#     ===================================== ====== ======
#                                            Min    Max
#     ===================================== ====== ======
#     radius (mean):                        6.981  28.11
#     texture (mean):                       9.71   39.28
#     perimeter (mean):                     43.79  188.5
#     area (mean):                          143.5  2501.0
#     smoothness (mean):                    0.053  0.163
#     compactness (mean):                   0.019  0.345
#     concavity (mean):                     0.0    0.427
#     concave points (mean):                0.0    0.201
#     symmetry (mean):                      0.106  0.304
#     fractal dimension (mean):             0.05   0.097
#     radius (standard error):              0.112  2.873
#     texture (standard error):             0.36   4.885
#     perimeter (standard error):           0.757  21.98
#     area (standard error):                6.802  542.2
#     smoothness (standard error):          0.002  0.031
#     compactness (standard error):         0.002  0.135
#     concavity (standard error):           0.0    0.396
#     concave points (standard error):      0.0    0.053
#     symmetry (standard error):            0.008  0.079
#     fractal dimension (standard error):   0.001  0.03
#     radius (worst):                       7.93   36.04
#     texture (worst):                      12.02  49.54
#     perimeter (worst):                    50.41  251.2
#     area (worst):                         185.2  4254.0
#     smoothness (worst):                   0.071  0.223
#     compactness (worst):                  0.027  1.058
#     concavity (worst):                    0.0    1.252
#     concave points (worst):               0.0    0.291
#     symmetry (worst):                     0.156  0.664
#     fractal dimension (worst):            0.055  0.208
#     ===================================== ====== ======
#
#     :Missing Attribute Values: None
#
#     :Class Distribution: 212 - Malignant, 357 - Benign
#
#     :Creator:  Dr. William H. Wolberg, W. Nick Street, Olvi L. Mangasarian
#
#     :Donor: Nick Street
#
#     :Date: November, 1995
#
# This is a copy of UCI ML Breast Cancer Wisconsin (Diagnostic) datasets.
# https://goo.gl/U2Uwz2
#
# Features are computed from a digitized image of a fine needle
# aspirate (FNA) of a breast mass.  They describe
# characteristics of the cell nuclei present in the image.
#
# Separating plane described above was obtained using
# Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree
# Construction Via Linear Programming." Proceedings of the 4th
# Midwest Artificial Intelligence and Cognitive Science Society,
# pp. 97-101, 1992], a classification method which uses linear
# programming to construct a decision tree.  Relevant features
# were selected using an exhaustive search in the space of 1-4
# features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane
# in the 3-dimensional space is that described in:
# [K. P. Bennett and O. L. Mangasarian: "Robust Linear
# Programming Discrimination of Two Linearly Inseparable Sets",
# Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server:
#
# ftp ftp.cs.wisc.edu
# cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# .. topic:: References
#
#    - W.N. Street, W.H. Wolberg and O.L. Mangasarian. Nuclear feature extraction
#      for breast tumor diagnosis. IS&T/SPIE 1993 International Symposium on
#      Electronic Imaging: Science and Technology, volume 1905, pages 861-870,
#      San Jose, CA, 1993.
#    - O.L. Mangasarian, W.N. Street and W.H. Wolberg. Breast cancer diagnosis and
#      prognosis via linear programming. Operations Research, 43(4), pages 570-577,
#      July-August 1995.
#    - W.H. Wolberg, W.N. Street, and O.L. Mangasarian. Machine learning techniques
#      to diagnose breast cancer from fine-needle aspirates. Cancer Letters 77 (1994)
#      163-171.

# %%
breast_cancer_Y = breast_cancer_data['target']
breast_cancer_X = breast_cancer_data['data']

# %%
Scaler = MinMaxScaler()

# %%
norm_breast_cancer_X = Scaler.fit_transform(breast_cancer_X)
norm_breast_cancer_X
# Out:
# array([[0.52103744, 0.0226581 , 0.54598853, ..., 0.91202749, 0.59846245,
#         0.41886396],
#        [0.64314449, 0.27257355, 0.61578329, ..., 0.63917526, 0.23358959,
#         0.22287813],
#        [0.60149557, 0.3902604 , 0.59574321, ..., 0.83505155, 0.40370589,
#         0.21343303],
#        ...,
#        [0.45525108, 0.62123774, 0.44578813, ..., 0.48728522, 0.12872068,
#         0.1519087 ],
#        [0.64456434, 0.66351031, 0.66553797, ..., 0.91065292, 0.49714173,
#         0.45231536],
#        [0.03686876, 0.50152181, 0.02853984, ..., 0.        , 0.25744136,
#         0.10068215]])

# %%
breast_cancer_X.shape
# Out:
# (569, 30)

# %%
def nonlin(x,deriv=False): #создание сигмоиды; в соответств от 0 до 1; преобр в вероятности;   deriv = True - производная
    if(deriv==True):
        return x*(1-(x))

    return 1/(1+np.exp(-x))
    
#X входной набор данных 
                
#y выходной набор данных
#l0 первый слой сети
#l1 -l2 - скрытые слои сети 
# l3 -финальный выходной слой - гипотеза
#syn - слои весов
# l2_error – промах сети в количественном выражении
# l2_delta – ошибка сети, в зависимости от уверенности предсказания. Почти совпадает с ошибкой, за исключением уверенных предсказаний
# l1_error – взвешивая l2_delta весами из syn1, мы подсчитываем ошибку в среднем/скрытом слое
# l1_delta – ошибки сети из l1, масштабируемые по увеернности предсказаний. Почти совпадает с l1_error, за исключением уверенных предсказаний
np.random.seed(1) #каждый раз одно и то же случайное распределение
# случайно инициализируем веса, в среднем - 0; «synapse zero» 
syn0 = 2*np.random.random((30,10)) - 1 #задаем веса и размер слоёв случайно;  матрица весов сети
syn1 = 2*np.random.random((10,3)) - 1 
syn2 = 2*np.random.random((3,1)) - 1
lr = 0.1
def suit(X, y, kolvo_epox):
    global syn0, syn1, syn2
    for i in range(kolvo_epox):
        #прямое распространение
        l0 = X
        l1 = nonlin(np.dot(l0,syn0)) 
        l2 = nonlin(np.dot(l1,syn1))
        l3 = nonlin(np.dot(l2,syn2))
        #обтратное распространение
        l3_error = y - l3 # в l1  догадки, сравниваем с реальностью, . l_error – вектор из положительных и отрицательных чисел, характеризующий «промах» сети.
        l3_delta = l3_error*nonlin(l3,deriv=True) #производная, взвешенная по ошибкам; уменьшаем ошибки предсказаний, сделанных с высокой уверенностью
        l2_error = l3_delta.dot(syn2.T)
        l2_delta = l2_error*nonlin(l2,deriv=True)
        l1_error = l2_delta.dot(syn1.T) #Использует ошибки, взвешенные по уверенности предсказаний из l2, чтобы подсчитать ошибку для l1; обратное распространение ошибок
        l1_delta = l1_error * nonlin(l1,deriv=True)
        #обновляем веса
        syn0 += lr*l0.T.dot(l1_delta) 
        syn1 += lr*l1.T.dot(l2_delta) 
        syn2 += lr*l2.T.dot(l3_delta)
        print('Значение функции потерь: ', np.mean(np.abs(l3_error)))
    return l3

# %%
breast_cancer_Y_reshaped = breast_cancer_Y.reshape(-1,1)

# %%
predict_breast_cancer_Y = suit(norm_breast_cancer_X, breast_cancer_Y_reshaped,1000)
# Out:
# Значение функции потерь:  0.5185850123327455
# Значение функции потерь:  0.41199301742905997
# Значение функции потерь:  0.4812774550713534
# Значение функции потерь:  0.4618306774532081
# Значение функции потерь:  0.43740453643044463
# Значение функции потерь:  0.4406889233398519
# Значение функции потерь:  0.4108076116550508
# Значение функции потерь:  0.446004220131922
# Значение функции потерь:  0.37850142840788864
# Значение функции потерь:  0.4802751993212109
# Значение функции потерь:  0.4612925029525833
# Значение функции потерь:  0.4081773126892305
# Значение функции потерь:  0.3538903817608704
# Значение функции потерь:  0.45826240884638697
# Значение функции потерь:  0.38147127640571404
# Значение функции потерь:  0.329000249089771
# Значение функции потерь:  0.46658367851537674
# Значение функции потерь:  0.4155640185955735
# Значение функции потерь:  0.3156714295729653
# Значение функции потерь:  0.43196219810501674
# Значение функции потерь:  0.3154315211942702
# Значение функции потерь:  0.3606884474014467
# Значение функции потерь:  0.2950074268007473
# Значение функции потерь:  0.46559906657834416
# Значение функции потерь:  0.4204210875250535
# Значение функции потерь:  0.3196326588561358
# Значение функции потерь:  0.30291947857769047
# Значение функции потерь:  0.3071332004171619
# Значение функции потерь:  0.28897068227598616
# Значение функции потерь:  0.3195440024688716
# Значение функции потерь:  0.27330793658892794
# Значение функции потерь:  0.40457421200975796
# Значение функции потерь:  0.27764373481285487
# Значение функции потерь:  0.3146117928233997
# Значение функции потерь:  0.266054020069313
# Значение функции потерь:  0.38422576957042504
# Значение функции потерь:  0.26585720556051745
# Значение функции потерь:  0.3316826447466972
# Значение функции потерь:  0.2603724150302579
# Значение функции потерь:  0.37939039795959134
# Значение функции потерь:  0.26397546747017636
# Значение функции потерь:  0.2991016595160399
# Значение функции потерь:  0.2573685027180871
# Значение функции потерь:  0.32678645178693405
# Значение функции потерь:  0.2540873863892871
# Значение функции потерь:  0.3514633471671864
# Значение функции потерь:  0.25355859865593233
# Значение функции потерь:  0.31629108666994016
# Значение функции потерь:  0.2511081508971464
# Значение функции потерь:  0.3255474120554976
# Значение функции потерь:  0.24973293818393547
# Значение функции потерь:  0.31820344569851144
# Значение функции потерь:  0.24844390562649715
# Значение функции потерь:  0.3120483036136785
# Значение функции потерь:  0.24722279342734385
# Значение функции потерь:  0.3069391200193394
# Значение функции потерь:  0.24605396853901088
# Значение функции потерь:  0.30275803262989465
# Значение функции потерь:  0.24492763892144762
# Значение функции потерь:  0.29936000817942404
# Значение функции потерь:  0.24383928817231254
# Значение функции потерь:  0.29659224087893044
# Значение функции потерь:  0.2427882350077259
# Значение функции потерь:  0.294306908583682
# Значение функции потерь:  0.24177574928478807
# Значение функции потерь:  0.2923712728733199
# Значение функции потерь:  0.2408033538320808
# Значение функции потерь:  0.290675614751694
# Значение функции потерь:  0.23987172282295127
# Значение функции потерь:  0.28913792420244283
# Значение функции потерь:  0.23898029049069097
# Значение функции потерь:  0.2877039110000398
# Значение функции потерь:  0.23812741901391382
# Значение функции потерь:  0.2863423450068966
# Значение функции потерь:  0.23731084008034212
# Значение функции потерь:  0.28503765625524735
# Значение функции потерь:  0.2365281054963643
# Значение функции потерь:  0.28378250894773643
# Значение функции потерь:  0.2357768952008216
# Значение функции потерь:  0.2825723533374823
# Значение функции потерь:  0.23505514958048598
# Значение функции потерь:  0.28140259794289707
# Значение функции потерь:  0.23436106669497425
# Значение функции потерь:  0.2802679639781076
# Значение функции потерь:  0.23369302831531613
# Значение функции потерь:  0.27916313317186775
# Значение функции потерь:  0.23304950930268772
# Значение функции потерь:  0.27808384468477243
# Значение функции потерь:  0.23242900361784558
# Значение функции потерь:  0.2770278595107614
# Значение функции потерь:  0.23182998135926294
# Значение функции потерь:  0.27599548140046315
# Значение функции потерь:  0.23125088006733743
# Значение функции потерь:  0.27498951388222437
# Значение функции потерь:  0.23069012853661305
# Значение функции потерь:  0.274014653076259
# Значение функции потерь:  0.23014619795745986
# Значение функции потерь:  0.27307641579083924
# Значение функции потерь:  0.22961766998592809
# Значение функции потерь:  0.27217981191072865
# Значение функции потерь:  0.2291033048722805
# Значение функции потерь:  0.2713280673937738
# Значение функции потерь:  0.22860208927709041
# Значение функции потерь:  0.2705217311017202
# Значение функции потерь:  0.22811324732539034
# Значение функции потерь:  0.2697584110957007
# Значение функции потерь:  0.22763621024486724
# Значение функции потерь:  0.269033197604197
# Значение функции потерь:  0.22717055463463648
# Значение функции потерь:  0.2683396136541099
# Значение функции потерь:  0.22671592966534854
# Значение функции потерь:  0.26767078241430114
# Значение функции потерь:  0.2262719945949789
# Значение функции потерь:  0.2670204726803148
# Значение функции потерь:  0.22583838058597575
# Значение функции потерь:  0.26638377953839115
# Значение функции потерь:  0.22541467977697513
# Значение функции потерь:  0.26575736025421043
# Значение функции потерь:  0.22500045534104318
# Значение функции потерь:  0.2651392993539236
# Значение функции потерь:  0.2245952619667347
# Значение функции потерь:  0.26452876450694696
# Значение функции потерь:  0.2241986668746267
# Значение функции потерь:  0.2639256210273407
# Значение функции потерь:  0.2238102651645066
# Значение функции потерь:  0.2633301204696017
# Значение функции потерь:  0.22342968758173465
# Значение функции потерь:  0.26274270693462587
# Значение функции потерь:  0.22305660199550084
# Значение функции потерь:  0.2621639261050065
# Значение функции потерь:  0.22269071135324073
# Значение функции потерь:  0.26159439218359
# Значение функции потерь:  0.22233175081519863
# Значение функции потерь:  0.2610347660581458
# Значение функции потерь:  0.22197948579476917
# Значение функции потерь:  0.26048571429048417
# Значение функции потерь:  0.22163371138624247
# Значение функции потерь:  0.25994784109515884
# Значение функции потерь:  0.22129425263821742
# Значение функции потерь:  0.2594216048637626
# Значение функции потерь:  0.22096096459120407
# Значение функции потерь:  0.25890724148926586
# Значение функции потерь:  0.22063373100042322
# Значение функции потерь:  0.258404717168482
# Значение функции потерь:  0.22031246110583894
# Значение функции потерь:  0.25791372517766276
# Значение функции потерь:  0.21999708447669153
# Значение функции потерь:  0.257433728234542
# Значение функции потерь:  0.21968754459029827
# Значение функции потерь:  0.2569640353108347
# Значение функции потерь:  0.21938379218670062
# Значение функции потерь:  0.25650389338314483
# Значение функции потерь:  0.21908577946399507
# Значение функции потерь:  0.2560525729317778
# Значение функции потерь:  0.21879345587554008
# Значение функции потерь:  0.2556094307842667
# Значение функции потерь:  0.21850676580385184
# Значение функции потерь:  0.25517394270512134
# Значение функции потерь:  0.2182256479042324
# Значение функции потерь:  0.25474570746007763
# Значение функции потерь:  0.2179500355873792
# Значение функции потерь:  0.254324430841683
# Значение функции потерь:  0.2176798580130491
# Значение функции потерь:  0.25390990073053327
# Значение функции потерь:  0.2174150410724936
# Значение функции потерь:  0.2535019628706571
# Значение функции потерь:  0.21715550805917713
# Значение функции потерь:  0.2531005031721461
# Значение функции потерь:  0.2169011799622266
# Значение функции потерь:  0.25270543798246026
# Значение функции потерь:  0.21665197548663614
# Значение функции потерь:  0.252316710472635
# Значение функции потерь:  0.2164078109752497
# Значение функции потерь:  0.25193428980697413
# Значение функции потерь:  0.21616860039027694
# Значение функции потерь:  0.25155816999071234
# Значение функции потерь:  0.2159342554433167
# Значение функции потерь:  0.25118836655708504
# Значение функции потерь:  0.21570468588445815
# Значение функции потерь:  0.2508249107630477
# Значение функции потерь:  0.2154797999037476
# Значение функции потерь:  0.2504678421009841
# Значение функции потерь:  0.21525950457485876
# Значение функции потерь:  0.25011720043137436
# Значение функции потерь:  0.21504370627768146
# Значение функции потерь:  0.2497730189452141
# Значение функции потерь:  0.2148323110609458
# Значение функции потерь:  0.24943531871133534
# Значение функции потерь:  0.2146252249336113
# Значение функции потерь:  0.24910410502847558
# Значение функции потерь:  0.21442235409427476
# Значение функции потерь:  0.24877936538916745
# Значение функции потерь:  0.21422360511721514
# Значение функции потерь:  0.24846106865904677
# Значение функции потерь:  0.21402888511319465
# Значение функции потерь:  0.2481491650629899
# Значение функции потерь:  0.21383810187703073
# Значение функции потерь:  0.2478435866715251
# Значение функции потерь:  0.21365116402677561
# Значение функции потерь:  0.24754424821151963
# Значение функции потерь:  0.2134679811341755
# Значение функции потерь:  0.24725104812465612
# Значение функции потерь:  0.2132884638439442
# Значение функции потерь:  0.24696386984401522
# Значение функции потерь:  0.21311252397969946
# Значение функции потерь:  0.24668258326211365
# Значение функции потерь:  0.21294007463587056
# Значение функции потерь:  0.24640704634606742
# Значение функции потерь:  0.21277103025629737
# Значение функции потерь:  0.2461371068388422
# Значение функции потерь:  0.2126053067009737
# Значение функции потерь:  0.24587260398147026
# Значение функции потерь:  0.21244282130238593
# Значение функции потерь:  0.24561337020054033
# Значение функции потерь:  0.21228349291246898
# Значение функции потерь:  0.2453592327224528
# Значение функции потерь:  0.21212724194070623
# Значение функции потерь:  0.24511001509385943
# Значение функции потерь:  0.21197399038357964
# Значение функции потерь:  0.2448655386016128
# Значение функции потерь:  0.21182366184549586
# Значение функции потерь:  0.2446256235939882
# Значение функции потерь:  0.21167618155141218
# Значение функции потерь:  0.24439009070882745
# Значение функции потерь:  0.21153147635156722
# Значение функции потерь:  0.24415876201539546
# Значение функции потерь:  0.21138947471890007
# Значение функции потерь:  0.2439314620766663
# Значение функции потерь:  0.21125010673988778
# Значение функции потерь:  0.2437080189382616
# Значение функции потерь:  0.21111330409963347
# Значение функции потерь:  0.2434882650495556
# Значение функции потерь:  0.21097900006211065
# Значение функции потерь:  0.24327203812143483
# Значение функции потерь:  0.21084712944652556
# Значение функции потерь:  0.24305918192376183
# Значение функции потерь:  0.21071762860079973
# Значение функции потерь:  0.24284954702371506
# Значение функции потерь:  0.21059043537320452
# Значение функции потерь:  0.24264299146396148
# Значение функции потерь:  0.21046548908319015
# Значение функции потерь:  0.24243938137722446
# Значение функции потерь:  0.21034273049244123
# Значение функции потерь:  0.24223859153139404
# Значение функции потерь:  0.21022210177715522
# Значение функции потерь:  0.24204050579708591
# Значение функции потерь:  0.21010354650247398
# Значение функции потерь:  0.24184501752765325
# Значение функции потерь:  0.20998700959989935
# Значение функции потерь:  0.24165202984028494
# Значение функции потерь:  0.20987243734838978
# Значение функции потерь:  0.24146145578614875
# Значение функции потерь:  0.20975977735966284
# Значение функции потерь:  0.24127321839773375
# Значение функции потерь:  0.20964897856802328
# Значение функции потерь:  0.2410872506027366
# Значение функции потерь:  0.20953999122479539
# Значение функции потерь:  0.24090349499609623
# Значение функции потерь:  0.20943276689717855
# Значение функции потерь:  0.24072190346512312
# Значение функции потерь:  0.20932725847106612
# Значение функции потерь:  0.2405424366670003
# Значение функции потерь:  0.2092234201570949
# Значение функции потерь:  0.24036506336306765
# Значение функции потерь:  0.20912120749893337
# Значение функции потерь:  0.24018975961996192
# Значение функции потерь:  0.20902057738259858
# Значение функции потерь:  0.24001650789349807
# Значение функции потерь:  0.20892148804542582
# Значение функции потерь:  0.2398452960167085
# Значение функции потерь:  0.20882389908322196
# Значение функции потерь:  0.2396761161182706
# Значение функции потерь:  0.2087277714541253
# Значение функции потерь:  0.23950896350120437
# Значение функции потерь:  0.20863306747777308
# Значение функции потерь:  0.23934383551387467
# Значение функции потерь:  0.20853975082855028
# Значение функции потерь:  0.2391807304457424
# Значение функции потерь:  0.2084477865219402
# Значение функции потерь:  0.23901964647889332
# Значение функции потерь:  0.20835714089330998
# Значение функции потерь:  0.23886058072321698
# Значение функции потерь:  0.2082677815688198
# Значение функции потерь:  0.23870352835844158
# Значение функции потерь:  0.20817967742850982
# Значение функции потерь:  0.23854848190044048
# Значение функции потерь:  0.20809279856197868
# Значение функции потерь:  0.2383954306027597
# Значение функции потерь:  0.20800711621738502
# Значение функции потерь:  0.23824435999769075
# Значение функции потерь:  0.2079226027447673
# Значение функции потерь:  0.23809525157489805
# Значение функции потерь:  0.2078392315348669
# Значение функции потерь:  0.2379480825900288
# Значение функции потерь:  0.2077569769547535
# Значение функции потерь:  0.23780282599119473
# Значение функции потерь:  0.20767581428158463
# Значение функции потерь:  0.23765945044790268
# Значение функции потерь:  0.20759571963579354
# Значение функции потерь:  0.23751792046499937
# Значение функции потерь:  0.2075166699149055
# Значение функции потерь:  0.23737819656341194
# Значение функции потерь:  0.20743864272903803
# Значение функции потерь:  0.23724023550978585
# Значение функции потерь:  0.2073616163389708
# Значение функции потерь:  0.23710399057833306
# Значение функции потерь:  0.20728556959748778
# Значение функции потерь:  0.2369694118300704
# Значение функции потерь:  0.20721048189450875
# Значение функции потерь:  0.23683644639691898
# Значение функции потерь:  0.20713633310635496
# Значение функции потерь:  0.2367050387606323
# Значение функции потерь:  0.20706310354933963
# Значение функции потерь:  0.2365751310190334
# Значение функции потерь:  0.20699077393774346
# Значение функции потерь:  0.23644666313443113
# Значение функции потерь:  0.20691932534613153
# Значение функции потерь:  0.23631957316125493
# Значение функции потерь:  0.20684873917588797
# Значение функции потерь:  0.2361937974518185
# Значение функции потерь:  0.20677899712579192
# Значение функции потерь:  0.2360692708406886
# Значение функции потерь:  0.2067100811664225
# Значение функции потерь:  0.23594592680937418
# Значение функции потерь:  0.20664197351816474
# Значение функции потерь:  0.23582369763398825
# Значение функции потерь:  0.20657465663258506
# Значение функции потерь:  0.23570251451919635
# Значение функции потерь:  0.2065081131769517
# Значение функции потерь:  0.23558230772218217
# Значение функции потерь:  0.20644232602168747
# Значение функции потерь:  0.23546300667057213
# Значение функции потерь:  0.20637727823055985
# Значение функции потерь:  0.23534454007829175
# Значение функции потерь:  0.20631295305343061
# Значение функции потерь:  0.23522683606321912
# Значение функции потерь:  0.20624933392140293
# Значение функции потерь:  0.23510982227027044
# Значение функции потерь:  0.20618640444422065
# Значение функции потерь:  0.23499342600322753
# Значение функции потерь:  0.20612414840978296
# Значение функции потерь:  0.23487757436821283
# Значение функции потерь:  0.20606254978564886
# Значение функции потерь:  0.2347621944312482
# Значение функции потерь:  0.20600159272240673
# Значение функции потерь:  0.23464721339181557
# Значение функции потерь:  0.2059412615587865
# Значение функции потерь:  0.23453255877377596
# Значение функции потерь:  0.2058815408283894
# Значение функции потерь:  0.23441815863441476
# Значение функции потерь:  0.20582241526790104
# Значение функции потерь:  0.23430394179177133
# Значение функции потерь:  0.20576386982665043
# Значение функции потерь:  0.234189838069795
# Значение функции потерь:  0.20570588967736234
# Значение функции потерь:  0.23407577856025805
# Значение функции потерь:  0.20564846022794572
# Значение функции потерь:  0.2339616958997627
# Значение функции потерь:  0.20559156713414575
# Значение функции потерь:  0.23384752455961857
# Значение функции потерь:  0.20553519631288175
# Значение функции потерь:  0.23373320114585355
# Значение функции потерь:  0.20547933395608367
# Значение функции потерь:  0.2336186647061705
# Значение функции потерь:  0.20542396654483555
# Значение функции потерь:  0.2335038570402879
# Значение функции потерь:  0.2053690808636325
# Значение функции потерь:  0.23338872300981853
# Значение функции потерь:  0.2053146640145578
# Значение функции потерь:  0.23327321084365335
# Значение функции потерь:  0.20526070343119301
# Значение функции потерь:  0.2331572724347439
# Значение функции потерь:  0.20520718689207967
# Значение функции потерь:  0.23304086362420792
# Значение функции потерь:  0.20515410253356603
# Значение функции потерь:  0.2329239444688313
# Значение функции потерь:  0.2051014388618823
# Значение функции потерь:  0.2328064794882927
# Значение функции потерь:  0.2050491847643096
# Значение функции потерь:  0.23268843788879218
# Значение функции потерь:  0.20499732951932306
# Значение функции потерь:  0.23256979376020612
# Значение функции потерь:  0.20494586280561217
# Значение функции потерь:  0.23245052624440832
# Значение функции потерь:  0.20489477470990222
# Значение функции потерь:  0.23233061967296476
# Значение функции потерь:  0.20484405573352002
# Значение функции потерь:  0.2322100636730231
# Значение функции потерь:  0.2047936967976696
# Значение функции потерь:  0.23208885324083944
# Значение функции потерь:  0.20474368924740052
# Значение функции потерь:  0.23196698878301605
# Значение функции потерь:  0.20469402485426905
# Значение функции потерь:  0.23184447612612913
# Значение функции потерь:  0.20464469581770708
# Значение функции потерь:  0.23172132649600785
# Значение функции потерь:  0.20459569476512535
# Значение функции потерь:  0.2315975564684562
# Значение функции потерь:  0.20454701475078713
# Значение функции потерь:  0.2314731878936977
# Значение функции потерь:  0.2044986492534948
# Значение функции потерь:  0.23134824779724886
# Значение функции потерь:  0.20445059217313735
# Значение функции потерь:  0.2312227682602983
# Значение функции потерь:  0.20440283782614582
# Значение функции потерь:  0.2310967862829899
# Значение функции потерь:  0.20435538093990754
# Значение функции потерь:  0.23097034363427107
# Значение функции потерь:  0.2043082166461848
# Значение функции потерь:  0.23084348669219526
# Значение функции потерь:  0.20426134047358294
# Значение функции потерь:  0.23071626627875572
# Значение функции потерь:  0.20421474833910802
# Значение функции потерь:  0.23058873749349423
# Значение функции потерь:  0.20416843653884983
# Значение функции потерь:  0.23046095955027474
# Значение функции потерь:  0.2041224017378216
# Значение функции потерь:  0.2303329956217549
# Значение функции потерь:  0.20407664095898143
# Значение функции потерь:  0.23020491269623142
# Значение функции потерь:  0.20403115157145646
# Значение функции потерь:  0.23007678145168653
# Значение функции потерь:  0.2039859312779821
# Значение функции потерь:  0.2299486761520319
# Значение функции потерь:  0.20394097810156414
# Значение функции потерь:  0.2298206745707329
# Значение функции потерь:  0.20389629037135928
# Значение функции потерь:  0.22969285794720912
# Значение функции потерь:  0.2038518667077612
# Значение функции потерь:  0.22956531098164867
# Значение функции потерь:  0.203807706006662
# Значение функции потерь:  0.22943812187413923
# Значение функции потерь:  0.2037638074228398
# Значение функции потерь:  0.22931138241431787
# Значение функции потерь:  0.20372017035239592
# Значение функции потерь:  0.2291851881280648
# Значение функции потерь:  0.20367679441412978
# Значение функции потерь:  0.22905963848811065
# Значение функции потерь:  0.20363367942969304
# Значение функции потерь:  0.22893483719578378
# Значение функции потерь:  0.2035908254023012
# Значение функции потерь:  0.22881089254148132
# Значение функции потерь:  0.20354823249370138
# Значение функции потерь:  0.22868791785177098
# Значение функции потерь:  0.20350590099899032
# Значение функции потерь:  0.22856603203129253
# Значение функции потерь:  0.20346383131874046
# Значение функции потерь:  0.22844536020775774
# Значение функции потерь:  0.20342202392771985
# Значение функции потерь:  0.22832603448825414
# Значение функции потерь:  0.20338047933926848
# Значение функции потерь:  0.22820819483460517
# Значение функции потерь:  0.2033391980641093
# Значение функции потерь:  0.22809199006451059
# Значение функции потерь:  0.2032981805620089
# Значение функции потерь:  0.22797757898329046
# Значение функции потерь:  0.20325742718424128
# Значение функции потерь:  0.22786513164781985
# Значение функции потерь:  0.20321693810421604
# Значение функции потерь:  0.22775483075903846
# Значение функции потерь:  0.20317671323288422
# Значение функции потерь:  0.2276468731712886
# Значение функции потерь:  0.20313675211458357
# Значение функции потерь:  0.22754147149434092
# Значение функции потерь:  0.20309705379778062
# Значение функции потерь:  0.2274388557453688
# Значение функции потерь:  0.20305761667365688
# Значение функции потерь:  0.22733927498058848
# Значение функции потерь:  0.2030184382735988
# Значение функции потерь:  0.22724299879592302
# Значение функции потерь:  0.202979515014329
# Значение функции потерь:  0.2271503185274663
# Значение функции потерь:  0.20294084187660488
# Значение функции потерь:  0.2270615478982895
# Значение функции потерь:  0.2029024120001043
# Значение функции потерь:  0.2269770227382025
# Значение функции потерь:  0.202864216173396
# Значение функции потерь:  0.22689709923433157
# Значение функции потерь:  0.20282624219401474
# Значение функции потерь:  0.2268221499364018
# Значение функции потерь:  0.20278847407020506
# Значение функции потерь:  0.2267525564225975
# Значение функции потерь:  0.2027508910340087
# Значение функции потерь:  0.22668869711159437
# Значение функции потерь:  0.2027134663370978
# Значение функции потерь:  0.2266309281738194
# Значение функции потерь:  0.20267616580959683
# Значение функции потерь:  0.22657955486455697
# Значение функции потерь:  0.2026389461836733
# Значение функции потерь:  0.22653478994295323
# Значение функции потерь:  0.2026017532262209
# Значение функции потерь:  0.22649669533361827
# Значение функции потерь:  0.20256451979975665
# Значение функции потерь:  0.22646510320507882
# Значение функции потерь:  0.20252716409055843
# Значение функции потерь:  0.2264395138610199
# Значение функции потерь:  0.20248958841776754
# Значение функции потерь:  0.2264189713476253
# Значение функции потерь:  0.2024516792620035
# Значение функции потерь:  0.22640192491453154
# Значение функции потерь:  0.20241330938766547
# Значение функции потерь:  0.22638609677872068
# Значение функции потерь:  0.20237434307813779
# Значение функции потерь:  0.22636839402906606
# Значение функции потерь:  0.20233464537529475
# Значение функции потерь:  0.22634492128262285
# Значение функции потерь:  0.20229409558008415
# Значение функции потерь:  0.2263111607678131
# Значение функции потерь:  0.20225260397670358
# Значение функции потерь:  0.22626237121070353
# Значение функции потерь:  0.20221012896510795
# Значение функции потерь:  0.22619420053525452
# Значение функции потерь:  0.20216669024820214
# Значение функции потерь:  0.22610341276383902
# Значение функции потерь:  0.20212237354238427
# Значение функции потерь:  0.2259885351501648
# Значение функции потерь:  0.20207732423605632
# Значение функции потерь:  0.22585020336367104
# Значение функции потерь:  0.20203173100968164
# Значение функции потерь:  0.22569106560789223
# Значение функции потерь:  0.20198580382311132
# Значение функции потерь:  0.2255152722518626
# Значение функции потерь:  0.20193975199401273
# Значение функции потерь:  0.2253277304602183
# Значение функции потерь:  0.20189376690479785
# Значение функции потерь:  0.22513335717946786
# Значение функции потерь:  0.2018480113422801
# Значение функции потерь:  0.22493650881924274
# Значение функции потерь:  0.20180261514982592
# Значение функции потерь:  0.22474065959770737
# Значение функции потерь:  0.2017576755956723
# Значение функции потерь:  0.22454830817312643
# Значение функции потерь:  0.20171326060157319
# Значение функции потерь:  0.2243610446889018
# Значение функции потерь:  0.20166941329661406
# Значение функции потерь:  0.22417970374465798
# Значение функции потерь:  0.20162615685429752
# Значение функции потерь:  0.22400454465961972
# Значение функции потерь:  0.20158349901207642
# Значение функции потерь:  0.22383542223117536
# Значение функции потерь:  0.2015414359890709
# Значение функции потерь:  0.22367192993459278
# Значение функции потерь:  0.2014999557156848
# Значение функции потерь:  0.22351351027628177
# Значение функции потерь:  0.20145904039909343
# Значение функции потерь:  0.22335953423221136
# Значение функции потерь:  0.20141866850182996
# Значение функции потерь:  0.22320935492987026
# Значение функции потерь:  0.20137881622995288
# Значение функции потерь:  0.22306234152545076
# Значение функции потерь:  0.20133945862768746
# Значение функции потерь:  0.22291789875944887
# Значение функции потерь:  0.2013005703663717
# Значение функции потерь:  0.22277547669412148
# Значение функции потерь:  0.2012621263025274
# Значение функции потерь:  0.2226345740668204
# Значение функции потерь:  0.20122410186608453
# Значение функции потерь:  0.2224947377368852
# Значение функции потерь:  0.201186473326897
# Значение функции потерь:  0.22235555993362277
# Значение функции потерь:  0.2011492179764901
# Значение функции потерь:  0.22221667443372775
# Значение функции потерь:  0.2011123142527352
# Значение функции потерь:  0.22207775238260608
# Значение функции потерь:  0.20107574182779195
# Значение функции потерь:  0.22193849819047054
# Значение функции потерь:  0.20103948167397695
# Значение функции потерь:  0.22179864574696878
# Значение функции потерь:  0.20100351611792686
# Значение функции потерь:  0.22165795507918354
# Значение функции потерь:  0.20096782889022924
# Значение функции потерь:  0.2215162095052773
# Значение функции потерь:  0.20093240517533112
# Значение функции потерь:  0.22137321329391074
# Значение функции потерь:  0.2008972316647744
# Значение функции потерь:  0.221228789816709
# Значение функции потерь:  0.20086229661546012
# Значение функции потерь:  0.22108278016994368
# Значение функции потерь:  0.20082758991357041
# Значение функции потерь:  0.2209350422372886
# Значение функции потерь:  0.20079310314385931
# Значение функции потерь:  0.2207854501648045
# Значение функции потерь:  0.20075882966319186
# Значение функции потерь:  0.22063389422020813
# Значение функции потерь:  0.2007247646763934
# Значение функции потерь:  0.22048028100973552
# Значение функции потерь:  0.20069090531164963
# Значение функции потерь:  0.22032453402673402
# Значение функции потерь:  0.20065725069183288
# Значение функции потерь:  0.22016659450603052
# Значение функции потерь:  0.20062380199724042
# Значение функции потерь:  0.2200064225567854
# Значение функции потерь:  0.20059056251430615
# Значение функции потерь:  0.2198439985437296
# Значение функции потерь:  0.20055753766394155
# Значение функции потерь:  0.2196793246822124
# Значение функции потерь:  0.2005247350023035
# Значение функции потерь:  0.21951242680622995
# Значение функции потерь:  0.20049216418605925
# Значение функции потерь:  0.21934335626047147
# Значение функции потерь:  0.20045983689371177
# Значение функции потерь:  0.21917219185739384
# Значение функции потерь:  0.20042776669437476
# Значение функции потерь:  0.21899904182850746
# Значение функции потерь:  0.20039596885569094
# Значение функции потерь:  0.21882404568566383
# Значение функции потерь:  0.20036446008352107
# Значение функции потерь:  0.2186473758936383
# Значение функции потерь:  0.20033325818775877
# Значение функции потерь:  0.21846923924042552
# Значение функции потерь:  0.2003023816713013
# Значение функции потерь:  0.21828987777747944
# Значение функции потерь:  0.20027184924294175
# Значение функции потерь:  0.21810956919008517
# Значение функции потерь:  0.2002416792597966
# Значение функции потерь:  0.21792862644998226
# Значение функции потерь:  0.20021188911077994
# Значение функции потерь:  0.21774739660045545
# Значение функции потерь:  0.20018249455937143
# Значение функции потерь:  0.21756625853079087
# Значение функции потерь:  0.2001535090711005
# Значение функции потерь:  0.2173856196146777
# Значение функции потерь:  0.2001249431581672
# Значение функции потерь:  0.2172059111179476
# Значение функции потерь:  0.20009680377963507
# Значение функции потерь:  0.21702758232639932
# Значение функции потерь:  0.20006909383967839
# Значение функции потерь:  0.21685109340459846
# Значение функции потерь:  0.20004181182742986
# Значение функции потерь:  0.21667690707013407
# Значение функции потерь:  0.20001495163911462
# Значение функции потерь:  0.2165054792515708
# Значение функции потерь:  0.19998850261572937
# Значение функции потерь:  0.2163372489869523
# Значение функции потерь:  0.19996244981737546
# Значение функции потерь:  0.2161726279060286
# Значение функции потерь:  0.19993677453897282
# Значение функции потерь:  0.21601198971494265
# Значение функции потерь:  0.19991145505270394
# Значение функции потерь:  0.21585566015805266
# Значение функции потерь:  0.19988646754207912
# Значение функции потерь:  0.21570390795974123
# Значение функции потерь:  0.19986178717338007
# Значение функции потерь:  0.2155569372432265
# Значение функции потерь:  0.19983738923497799
# Значение функции потерь:  0.2154148818802806
# Значение функции потерь:  0.19981325026589586
# Значение функции потерь:  0.21527780214576206
# Значение функции потерь:  0.1997893490935508
# Значение функции потерь:  0.21514568393825503
# Значение функции потерь:  0.19976566770737525
# Значение функции потерь:  0.21501844069066217
# Значение функции потерь:  0.19974219190931894
# Значение функции потерь:  0.21489591794280802
# Значение функции потерь:  0.19971891170230144
# Значение функции потерь:  0.21477790039398104
# Значение функции потерь:  0.1996958214009594
# Значение функции потерь:  0.21466412110908611
# Значение функции потерь:  0.19967291947260513
# Значение функции потерь:  0.21455427242887207
# Значение функции потерь:  0.1996502081374233
# Значение функции потерь:  0.21444801804162625
# Значение функции потерь:  0.1996276927734075
# Значение функции потерь:  0.21434500561707187
# Значение функции потерь:  0.199605381182079
# Значение функции потерь:  0.21424487938604608
# Значение функции потерь:  0.1995832827753017
# Значение функции потерь:  0.21414729207172792
# Значение функции потерь:  0.1995614077420459
# Значение функции потерь:  0.21405191563656648
# Значение функции потерь:  0.1995397662479316
# Значение функции потерь:  0.21395845039794786
# Значение функции потерь:  0.19951836771129497
# Значение функции потерь:  0.21386663217745505
# Значение функции потерь:  0.19949722018888483
# Значение функции потерь:  0.2137762372745897
# Значение функции потерь:  0.19947632989340333
# Значение функции потерь:  0.21368708518689222
# Значение функции потерь:  0.1994557008548863
# Значение функции потерь:  0.21359903912571512
# Значение функции потерь:  0.19943533472890485
# Значение функции потерь:  0.21351200449258295
# Значение функции потерь:  0.19941523074694914
# Значение функции потерь:  0.2134259255786607
# Значение функции потерь:  0.19939538579807586
# Значение функции потерь:  0.2133407808246195
# Значение функции потерь:  0.19937579462581623
# Значение функции потерь:  0.213256577027302
# Значение функции потерь:  0.19935645012030057
# Значение функции потерь:  0.21317334290210554
# Значение функции потерь:  0.19933734368249806
# Значение функции потерь:  0.21309112240675945
# Значение функции потерь:  0.1993184656354279
# Значение функции потерь:  0.21300996820556772
# Значение функции потерь:  0.19929980565629565
# Значение функции потерь:  0.21292993560688644
# Значение функции потерь:  0.19928135320387577
# Значение функции потерь:  0.21285107724520488
# Значение функции потерь:  0.19926309791721028
# Значение функции потерь:  0.21277343870784524
# Значение функции потерь:  0.19924502996479998
# Значение функции потерь:  0.21269705523032625
# Значение функции потерь:  0.19922714032780284
# Значение функции потерь:  0.2126219495089799
# Значение функции потерь:  0.19920942100601607
# Значение функции потерь:  0.21254813060909697
# Значение функции потерь:  0.1991918651412098
# Значение функции потерь:  0.21247559388555246
# Значение функции потерь:  0.19917446705821776
# Значение функции потерь:  0.21240432178339574
# Значение функции потерь:  0.1991572222296038
# Значение функции потерь:  0.21233428535010795
# Значение функции потерь:  0.19914012717428686
# Значение функции потерь:  0.2122654462698562
# Значение функции потерь:  0.19912317930391196
# Значение функции потерь:  0.2121977592228466
# Значение функции потерь:  0.1991063767328251
# Значение функции потерь:  0.2121311743786371
# Значение функции потерь:  0.19908971806820827
# Значение функции потерь:  0.21206563984915702
# Значение функции потерь:  0.1990732021963543
# Значение функции потерь:  0.21200110395283167
# Значение функции потерь:  0.1990568280794076
# Значение функции потерь:  0.21193751717295872
# Значение функции потерь:  0.199040594574423
# Значение функции потерь:  0.2118748337285842
# Значение функции потерь:  0.19902450028359897
# Значение функции потерь:  0.21181301271191263
# Значение функции потерь:  0.19900854344131008
# Значение функции потерь:  0.21175201878037012
# Значение функции потерь:  0.1989927218403612
# Значение функции потерь:  0.21169182242179832
# Значение функции потерь:  0.19897703279693282
# Значение функции потерь:  0.21163239983636636
# Значение функции потерь:  0.19896147315115612
# Значение функции потерь:  0.21157373249763897
# Значение функции потерь:  0.19894603929825808
# Значение функции потерь:  0.21151580646737433
# Значение функции потерь:  0.19893072724382016
# Значение функции потерь:  0.21145861154410325
# Значение функции потерь:  0.19891553267591125
# Значение функции потерь:  0.21140214032486487
# Значение функции потерь:  0.1989004510466612
# Значение функции потерь:  0.21134638725352786
# Значение функции потерь:  0.1988854776561735
# Значение функции потерь:  0.2112913477190435
# Значение функции потерь:  0.19887060773244655
# Значение функции потерь:  0.21123701725403649
# Значение функции потерь:  0.19885583650207145
# Значение функции потерь:  0.2111833908696622
# Значение функции потерь:  0.19884115924778542
# Значение функции потерь:  0.21113046254788423
# Значение функции потерь:  0.19882657135036025
# Значение функции потерь:  0.21107822489834344
# Значение функции потерь:  0.19881206831368325
# Значение функции потерь:  0.2110266689746804
# Значение функции потерь:  0.19879764577314812
# Значение функции потерь:  0.21097578423515215
# Значение функции потерь:  0.19878329948853188
# Значение функции потерь:  0.2109255586250211
# Значение функции потерь:  0.19876902532334872
# Значение функции потерь:  0.2108759787535988
# Значение функции потерь:  0.19875481921320473
# Значение функции потерь:  0.21082703013688542
# Значение функции потерь:  0.19874067712593585
# Значение функции потерь:  0.21077869747717667
# Значение функции потерь:  0.19872659501631118
# Значение функции потерь:  0.2107309649533867
# Значение функции потерь:  0.1987125687778603
# Значение функции потерь:  0.2106838164996704
# Значение функции потерь:  0.19869859419399016
# Значение функции потерь:  0.21063723605469198
# Значение функции потерь:  0.19868466689004063
# Значение функции потерь:  0.2105912077690764
# Значение функции потерь:  0.1986707822873495
# Значение функции потерь:  0.21054571616374243
# Значение функции потерь:  0.19865693555980246
# Значение функции потерь:  0.2105007462365714
# Значение функции потерь:  0.19864312159277345
# Значение функции потерь:  0.21045628351893783
# Значение функции потерь:  0.1986293349438509
# Значение функции потерь:  0.21041231408683053
# Значение функции потерь:  0.19861556980431125
# Значение функции потерь:  0.21036882453354486
# Значение функции потерь:  0.19860181995995313
# Значение функции потерь:  0.21032580191222863
# Значение функции потерь:  0.19858807874964626
# Значение функции потерь:  0.21028323365698867
# Значение функции потерь:  0.19857433901975732
# Значение функции потерь:  0.21024110749094319
# Значение функции потерь:  0.1985605930724842
# Значение функции потерь:  0.2101994113286929
# Значение функции потерь:  0.19854683260602823
# Значение функции потерь:  0.2101581331793613
# Значение функции потерь:  0.19853304864443475
# Значение функции потерь:  0.21011726105479042
# Значение функции потерь:  0.19851923145480788
# Значение функции потерь:  0.21007678288583748
# Значение функции потерь:  0.1985053704494242
# Значение функции потерь:  0.21003668644812135
# Значение функции потерь:  0.1984914540699934
# Значение функции потерь:  0.20999695929712672
# Значение функции потерь:  0.1984774696509159
# Значение функции потерь:  0.20995758871134293
# Значение функции потерь:  0.19846340325782497
# Значение функции потерь:  0.20991856164112918
# Значение функции потерь:  0.19844923949693144
# Значение функции потерь:  0.20987986466025327
# Значение функции потерь:  0.19843496128966212
# Значение функции потерь:  0.2098414839165188
# Значение функции потерь:  0.1984205496057342
# Значение функции потерь:  0.20980340507752326
# Значение функции потерь:  0.19840598314604824
# Значение функции потерь:  0.20976561326730606
# Значение функции потерь:  0.1983912379644963
# Значение функции потерь:  0.20972809298936876
# Значение функции потерь:  0.19837628701481355
# Значение функции потерь:  0.2096908280311775
# Значение функции потерь:  0.19836109960472698
# Значение функции потерь:  0.20965380134468273
# Значение функции потерь:  0.19834564073456734
# Значение функции потерь:  0.2096169948964805
# Значение функции потерь:  0.19832987029078145
# Значение функции потерь:  0.20958038947982346
# Значение функции потерь:  0.19831374205578978
# Значение функции потерь:  0.2095439644785666
# Значение функции потерь:  0.19829720248351124
# Значение функции потерь:  0.20950769756999194
# Значение функции потерь:  0.1982801891733408
# Значение функции потерь:  0.20947156434888284
# Значение функции потерь:  0.1982626289525668
# Значение функции потерь:  0.20943553784856808
# Значение функции потерь:  0.1982444354453829
# Значение функции потерь:  0.20939958792494923
# Значение функции потерь:  0.19822550596164676
# Значение функции потерь:  0.20936368045523834
# Значение функции потерь:  0.19820571747400978
# Значение функции потерь:  0.20932777628182328
# Значение функции потерь:  0.1981849213581458
# Значение функции потерь:  0.20929182979939878
# Значение функции потерь:  0.1981629364319394
# Значение функции потерь:  0.20925578703369732
# Значение функции потерь:  0.19813953962048264
# Значение функции потерь:  0.20921958298176202
# Значение функции потерь:  0.19811445325301352
# Значение функции потерь:  0.2091831378575404
# Значение функции потерь:  0.19808732749528377
# Значение функции потерь:  0.20914635167856355
# Значение функции потерь:  0.19805771561436317
# Значение функции потерь:  0.20910909627725846
# Значение функции потерь:  0.1980250384447552
# Значение функции потерь:  0.20907120320624747
# Значение функции потерь:  0.19798853217269013
# Значение функции потерь:  0.2090324449002987
# Значение функции потерь:  0.19794716960923794
# Значение функции потерь:  0.20899250438872558
# Значение функции потерь:  0.19789953794445736
# Значение функции потерь:  0.20895092481953165
# Значение функции потерь:  0.1978436423449005
# Значение функции потерь:  0.20890702181125442
# Значение функции потерь:  0.1977765775588291
# Значение функции потерь:  0.20885972382529067
# Значение функции потерь:  0.19769395216064167
# Значение функции потерь:  0.20880726461742216
# Значение функции потерь:  0.19758881959954955
# Значение функции потерь:  0.20874654913925436
# Значение функции потерь:  0.1974495482793704
# Значение функции потерь:  0.2086717320139699
# Значение функции потерь:  0.1972551804450835
# Значение функции потерь:  0.20857067192015752
# Значение функции потерь:  0.19696406148016066
# Значение функции потерь:  0.2084147405709918
# Значение функции потерь:  0.1964811175377206
# Значение функции потерь:  0.20812305288378571
# Значение функции потерь:  0.19553855309832321
# Значение функции потерь:  0.20739172142734358
# Значение функции потерь:  0.19305476975968772
# Значение функции потерь:  0.20428468093915814
# Значение функции потерь:  0.17978829342419383
# Значение функции потерь:  0.16416772670920046
# Значение функции потерь:  0.13228344440117812
# Значение функции потерь:  0.37846814938415696
# Значение функции потерь:  0.256404571360304
# Значение функции потерь:  0.15217864850140903
# Значение функции потерь:  0.12245571498782261
# Значение функции потерь:  0.15324209882242942
# Значение функции потерь:  0.15615155034961742
# Значение функции потерь:  0.18019777285707875
# Значение функции потерь:  0.19267221587809216
# Значение функции потерь:  0.12858059689127302
# Значение функции потерь:  0.11115921131238232
# Значение функции потерь:  0.10764710664504483
# Значение функции потерь:  0.11259096108995226
# Значение функции потерь:  0.1062212548985677
# Значение функции потерь:  0.11402508853173413
# Значение функции потерь:  0.09824642602330284
# Значение функции потерь:  0.12590423182671903
# Значение функции потерь:  0.14725067210549303
# Значение функции потерь:  0.12979071464918956
# Значение функции потерь:  0.11874815126839895
# Значение функции потерь:  0.10229513781407643
# Значение функции потерь:  0.08854141276538983
# Значение функции потерь:  0.11507870501931931
# Значение функции потерь:  0.09028263358103338
# Значение функции потерь:  0.11882159539921448
# Значение функции потерь:  0.10362094981647418
# Значение функции потерь:  0.10757177078787378
# Значение функции потерь:  0.06993856490629151
# Значение функции потерь:  0.08981906888575965
# Значение функции потерь:  0.07613634858163751
# Значение функции потерь:  0.11340545501729042
# Значение функции потерь:  0.1054679252229752
# Значение функции потерь:  0.10983867791589469
# Значение функции потерь:  0.0735124544264545
# Значение функции потерь:  0.09994057609720071
# Значение функции потерь:  0.06348441670666842
# Значение функции потерь:  0.07792349821066857
# Значение функции потерь:  0.08270784410627974
# Значение функции потерь:  0.13265112967521592
# Значение функции потерь:  0.16919530945900318
# Значение функции потерь:  0.1311490918412718
# Значение функции потерь:  0.0974747265390966
# Значение функции потерь:  0.10278848386149661
# Значение функции потерь:  0.0612608088032919
# Значение функции потерь:  0.06191469482043064
# Значение функции потерь:  0.07040309086398697
# Значение функции потерь:  0.08804024840231502
# Значение функции потерь:  0.06610373204927886
# Значение функции потерь:  0.0794968629248954
# Значение функции потерь:  0.07593273523935767
# Значение функции потерь:  0.11046793669245829
# Значение функции потерь:  0.0827911735176916
# Значение функции потерь:  0.1139848276398521
# Значение функции потерь:  0.08241635052925879
# Значение функции потерь:  0.1126866446268742
# Значение функции потерь:  0.07077528157606992
# Значение функции потерь:  0.08580420833241684
# Значение функции потерь:  0.05977343697709959
# Значение функции потерь:  0.059101567384994794
# Значение функции потерь:  0.06252583353392895
# Значение функции потерь:  0.0660520377548022
# Значение функции потерь:  0.07233794135182418
# Значение функции потерь:  0.09338210554945536
# Значение функции потерь:  0.06478490805213889
# Значение функции потерь:  0.07016516888985916
# Значение функции потерь:  0.07266663755526183
# Значение функции потерь:  0.09223632363021238
# Значение функции потерь:  0.06522618789345043
# Значение функции потерь:  0.06968312934907697
# Значение функции потерь:  0.06985181273535501
# Значение функции потерь:  0.0824617886949332
# Значение функции потерь:  0.06941716831360432
# Значение функции потерь:  0.07967737111863027
# Значение функции потерь:  0.07034394421068445
# Значение функции потерь:  0.08121595346958495
# Значение функции потерь:  0.07038800078174093
# Значение функции потерь:  0.08016034004387713
# Значение функции потерь:  0.07053569959940716
# Значение функции потерь:  0.07957513115586945
# Значение функции потерь:  0.07038815070509691
# Значение функции потерь:  0.07826583602982883
# Значение функции потерь:  0.06935372849091041
# Значение функции потерь:  0.07482851956299215
# Значение функции потерь:  0.06533290683992585
# Значение функции потерь:  0.0650820530929031
# Значение функции потерь:  0.054278240847955114
# Значение функции потерь:  0.049404505607784505
# Значение функции потерь:  0.049758799782372895
# Значение функции потерь:  0.04645771353872329
# Значение функции потерь:  0.04722723230556603
# Значение функции потерь:  0.045462020355985136
# Значение функции потерь:  0.04595660564581319
# Значение функции потерь:  0.0449894509408846
# Значение функции потерь:  0.04536103208701596
# Значение функции потерь:  0.04464194148520258
# Значение функции потерь:  0.04493872566996306
# Значение функции потерь:  0.044332466410882544
# Значение функции потерь:  0.04457485563872922
# Значение функции потерь:  0.04404743252331114
# Значение функции потерь:  0.0442496184867067
# Значение функции потерь:  0.04378250560735937
# Значение функции потерь:  0.043957091510403785
# Значение функции потерь:  0.043534341303250824
# Значение функции потерь:  0.04369303419596917
# Значение функции потерь:  0.0432998896867581
# Значение функции потерь:  0.04345389924440105
# Значение функции потерь:  0.043076363923635314
# Значение функции потерь:  0.04323718877240866
# Значение функции потерь:  0.04286119056324607
# Значение функции потерь:  0.04304192483312603
# Значение функции потерь:  0.0426519623075277
# Значение функции потерь:  0.04286935807908081
# Значение функции потерь:  0.04244650285460446
# Значение функции потерь:  0.042724359133256055
# Значение функции потерь:  0.04224327527302915
# Значение функции потерь:  0.042618358747251874
# Значение функции потерь:  0.04204269166897196
# Значение функции потерь:  0.042575584061628084
# Значение функции потерь:  0.04185052437365074
# Значение функции потерь:  0.042645576126404176

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(breast_cancer_Y,np.squeeze(np.round(predict_breast_cancer_Y)))
# Out:
# 0.984182776801406

# %% [markdown]
# # ВЫВОДЫ:
#     Таким образом, вес первого входа по отношению к выходу будет постоянно увеличиваться или оставаться постоянным, а два других веса будут увеличиваться и уменьшаться в зависимости от примеров. Этот эффект и способствует обучению сети на основе корреляций входных и выходных данных.
